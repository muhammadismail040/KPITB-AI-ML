# %%
import numpy as np

# %% [markdown]
# # Create the RGB Image Array

# %%
image = np.random.rand(224, 224, 3)

# %% [markdown]
# # Print Image

# %%
print("Image shape:", image.shape)
# Out:
# Image shape: (224, 224, 3)

# %% [markdown]
# # Explain Dimention

# %%
print("Explanation of dimensions:")
print("224  → Image height (number of rows)")
print("224  → Image width (number of columns)")
print("3    → Color channels (Red, Green, Blue)")
# Out:
# Explanation of dimensions:
# 224  → Image height (number of rows)
# 224  → Image width (number of columns)
# 3    → Color channels (Red, Green, Blue)
