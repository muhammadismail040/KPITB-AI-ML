# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x = np.array([[500], [800], [1000], [1200]])
y = np .array([50, 80, 100, 120])

# %%
model = LinearRegression()
model.fit(x,y)
print("Prediction for 900 sqrft: ",model.predict([[900]]))
# Out:
# Prediction for 900 sqrft:  [90.]

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.plot(x,model.predict(x))
plt.xlabel("Area")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ## Ridge regression is used to prevent overfitting and handle multicollinearity (when features are highly correlated).

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha = 1.0)
ridge.fit(x, y)
print("Ridge prediction: ",ridge.predict([[900]]))
# Out:
# Ridge prediction:  [89.99999065]

# %% [markdown]
# ## Lasso Regression
#
# Lasso Regression (Least Absolute Shrinkage and Selection Operator) is a type of linear regression that uses shrinkage. Shrinkage means that coefficients are shrunk towards zero. Lasso regression is useful for feature selection and regularization to prevent overfitting, especially when dealing with many features. It adds a penalty equal to the absolute value of the magnitude of coefficients. Let's implement it with our data.

# %%
from sklearn.linear_model import Lasso

lasso = Lasso(alpha = 1.0)
lasso.fit(x, y)
print("Lasso prediction: ",lasso.predict([[900]]))
# Out:
# Lasso prediction:  [89.99962617]
